# %%
import sys
sys.path.append("../common_scripts/")

from common_functions import save_batch, print_sample, count_tokens, create_formatted_samples_for_eval
from eval_prompts import *
from pathlib import Path
import pandas as pd
import json


from datetime import datetime
import time

import fsspec
import os

test_df = pd.read_csv("../../dataset_for_hf/test.csv")

# %% [markdown]
# # deepseek

# %% [markdown]
# ## zero-shot

# %%
def create_formatted_inputs_for_zero_shot_eval(row):
    # Adding label for ID since there are d-d questions with both bio & mol interactions.
    return {"custom_id": f"{row.Entities}_{row.Label}:zero_shot",
            "body": {"model": 'deepseek-reasoner',
                     "messages": [
                                     {"role": "system", "content": SYSTEM_PROMPT_ZERO_SHOT},
                                     {"role": "user", "content": USER_PROMPT_ZERO_SHOT.format(row.Question)}
                                 ]
                    }
           }

formatted_samples = [create_formatted_inputs_for_zero_shot_eval(row) for row in test_df.itertuples()]
save_batch(formatted_samples, "../../samples_for_eval/zero_shot/deepseek/batch_input_r1.jsonl")

# %%
def run_deepseek_inference(input_path, output_path):
    responses = []
    with open(input_path, 'r') as f:
        for line in f:
            sample = json.loads(line.strip())
            messages = sample["body"]["messages"]
            model = sample["body"]["model"]
            
            try:
                response = client.chat.completions.create(
                    model=model,
                    messages=messages,
                    stream=False
                )
                output = {
                    "custom_id": sample["custom_id"],
                    "response": response.choices[0].message.content
                }
            except Exception as e:
                output = {
                    "custom_id": sample["custom_id"],
                    "response": f"[ERROR] {str(e)}"
                }

            responses.append(output)

    # Save responses
    with open(output_path, 'w') as f:
        for r in responses:
            f.write(json.dumps(r) + '\n')

    print(f"Saved {len(responses)} results to {output_path}")

# %%
import json
from openai import OpenAI

# Set up client
client = OpenAI(api_key="", base_url="https://api.deepseek.com")
run_deepseek_inference('../../samples_for_eval/zero_shot/deepseek/batch_input_r1.jsonl', "../../samples_for_eval/zero_shot/deepseek/responses_r1.jsonl")

# %% [markdown]
# ## upper-bound

# %%
def create_formatted_inputs_for_upper_bound_eval(row):
    return {
        "custom_id": f"{row.Entities}_{row.Label}:upper_bound",
        "body": {
            "model": 'deepseek-reasoner',
            "messages": [
                {"role": "system", "content": SYSTEM_PROMPT_ZERO_SHOT},
                {"role": "user", "content": f"QUESTION: {row.Question}\n\nRELEVANT KNOWLEDGE: {row.Question_Background}"}
            ]
        }
    }

# Apply to test_df
formatted_upper_bound = [create_formatted_inputs_for_upper_bound_eval(row) for row in test_df.itertuples()]
save_batch(formatted_upper_bound, "../../samples_for_eval/upper_bound/deepseek/batch_input.jsonl")

# %%
import json
from openai import OpenAI

client = OpenAI(api_key="", base_url="https://api.deepseek.com")
run_deepseek_inference('../../samples_for_eval/upper_bound/deepseek/batch_input.jsonl', "../../samples_for_eval/upper_bound/deepseek/responses_r1.jsonl")

# %% [markdown]
# # Qwen

# %% [markdown]
# ## zero-shot

# %%
def create_formatted_inputs_for_zero_shot_eval(row):
    return {
        "custom_id": f"{row.Entities}_{row.Label}:zero_shot",
        "body": {
            "model": "Qwen/Qwen3-235B-A22B-fp8-tput",  # adjust model name as per API
            "messages": [
                {"role": "system", "content": SYSTEM_PROMPT_ZERO_SHOT},
                {"role": "user", "content": USER_PROMPT_ZERO_SHOT.format(row.Question)}
            ]
        }
    }
zero_shot_samples = [create_formatted_inputs_for_zero_shot_eval(row) for row in test_df.itertuples()]
save_batch(zero_shot_samples, "../../samples_for_eval/zero_shot/qwen/batch_input_new.jsonl")

# %% [markdown]
# ## upper_bound

# %%
def create_formatted_inputs_for_qwen_gold(row):
    return {
        "custom_id": f"{row.Entities}_{row.Label}:gold_injected",
        "body": {
            "model": 'Qwen/Qwen3-235B-A22B-fp8-tput', #"qwen/qwen3-235b-a22b:free",
            "messages": [
                {"role": "system", "content": SYSTEM_PROMPT_ZERO_SHOT},
                {"role": "user", "content": f"Question: {row.Question}\n\nGold Evidence:\n{row.Question_Background}\n\nAnswer:"}
            ]
        }
    }
gold_samples = [create_formatted_inputs_for_qwen_gold(row) for row in test_df.itertuples()]
save_batch(gold_samples, "../../samples_for_eval/upper_bound/qwen/batch_input_all.jsonl")

# %%
import os
from together import Together
def run_qwen3_inference(input_path, output_path):
    client = Together(api_key='')
    # Step 1: Read already completed custom_ids
    completed_ids = set()
    if os.path.exists(output_path):
        with open(output_path, 'r') as f_out:
            for line in f_out:
                try:
                    obj = json.loads(line)
                    completed_ids.add(obj["custom_id"])
                except:
                    continue
    print(f"Found {len(completed_ids)} completed responses. Resuming from last point...")
    # Step 2: Begin line-by-line inference
    with open(input_path, 'r') as f_in, open(output_path, 'a') as f_out:
        for line in f_in:
            sample = json.loads(line.strip())
            custom_id = sample["custom_id"]
            if custom_id in completed_ids:
                continue  # Skip already processed
            messages = sample["body"]["messages"]
            model = sample["body"]["model"]
            try:
                completion = client.chat.completions.create(
                    model=model,
                    messages=messages,
                    extra_body={}
                )

                if completion.choices and completion.choices[0].message and completion.choices[0].message.content:
                    content = completion.choices[0].message.content
                else:
                    content = "[ERROR] Empty or malformed response."

                result = {
                    "custom_id": custom_id,
                    "response": content
                }
            except Exception as e:
                result = {
                    "custom_id": custom_id,
                    "response": f"[ERROR] {str(e)}"
                }

            f_out.write(json.dumps(result) + "\n")
            f_out.flush()  # Immediately write to disk
            print(f"Processed: {custom_id}")

# %%
run_qwen3_inference('../../samples_for_eval/zero_shot/qwen/batch_input_new.jsonl', '../../samples_for_eval/zero_shot/qwen/responses_new.jsonl')
# Out:
# Found 142 completed responses. Resuming from last point...
# Processed: acetazolamide-Haloperidol-Rosiglitazone-Bimatoprost_2:zero_shot
# Processed: Naproxen-alendronic acid_0:zero_shot
# Processed: Aciclovir-Doxazosin-Alpha-1B adrenergic receptor_7:zero_shot
# Processed: Risedronic acid-Zolpidem_3:zero_shot
# Processed: Amlodipine-vincristine_0:zero_shot
# Processed: Temazepam-Trimipramine-Histamine H1 receptor_7:zero_shot
# Processed: Naproxen-Risedronic acid-vincristine-Torasemide_2:zero_shot
# Processed: Duloxetine-desvenlafaxine_3:zero_shot
# Processed: Aciclovir-Dipyridamole_0:zero_shot
# Processed: Celecoxib-Palonosetron_0:zero_shot
# Processed: Methylphenidate-Modafinil-Pamidronic acid-thiotepa_5:zero_shot
# Processed: Desloratadine-solifenacin_0:zero_shot
# Processed: Naproxen-hydroxychloroquine_3:zero_shot
# Processed: Citalopram-Fenofibrate_0:zero_shot
# Processed: Telmisartan-Cinacalcet_0:zero_shot
# Processed: Rofecoxib-Torasemide_3:zero_shot
# Processed: Lamotrigine-Dexpramipexole_3:zero_shot
# Processed: Alprazolam-Doxazosin_0:zero_shot
# Processed: Ciclopirox-hydroxychloroquine_0:zero_shot
# Processed: alendronic acid-Ibuprofen_3:zero_shot
# Processed: Celecoxib-Labetalol-Metoprolol-Gastrin-releasing peptide receptor_8:zero_shot
# Processed: Duloxetine-Darunavir_0:zero_shot
# Processed: Minoxidil-Perindopril_3:zero_shot
# Processed: Oxaprozin-Sildenafil_3:zero_shot
# Processed: Ibuprofen-Repaglinide_3:zero_shot
# Processed: Trazodone-Alpha-2C adrenergic receptor_6:zero_shot

# %%
run_qwen3_inference('../../samples_for_eval/upper_bound/qwen/batch_input_all.jsonl', "../../samples_for_eval/upper_bound/qwen/responses.jsonl")
# Out:
# Saved 168 results to ../../samples_for_eval/upper_bound/qwen/responses.jsonl

# %% [markdown]
# # Llama

# %% [markdown]
# ## zero-shot

# %%
from together import Together
def create_formatted_inputs_for_zero_shot_eval(row):
    return {
        "custom_id": f"{row.Entities}_{row.Label}:zero_shot",
        "method": "POST",
        "url": "/v1/chat/completions",  # still standard for OpenAI-compatible endpoints
        "body": {
            "model": "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo",  # adjust model name as per API
            "messages": [
                {"role": "system", "content": SYSTEM_PROMPT_ZERO_SHOT},
                {"role": "user", "content": USER_PROMPT_ZERO_SHOT.format(row.Question)}
            ]
        }
    }

formatted_samples = [create_formatted_inputs_for_zero_shot_eval(row) for row in test_df.itertuples()]
save_batch(formatted_samples, "../../samples_for_eval/zero_shot/llama/batch_input.jsonl")

# %%
import json
from openai import OpenAI  # Or relevant client for Fireworks / Together.ai
client = Together(api_key='')

def run_llama3_inference(input_path, output_path):
    responses = []
    with open(input_path, 'r') as f:
        for line in f:
            sample = json.loads(line.strip())
            messages = sample["body"]["messages"]
            model = sample["body"]["model"]

            try:
                response = client.chat.completions.create(
                    model=model,
                    messages=messages,
                    stream=False
                )
                output = {
                    "custom_id": sample["custom_id"],
                    "response": response.choices[0].message.content
                }
            except Exception as e:
                output = {
                    "custom_id": sample["custom_id"],
                    "response": f"[ERROR] {str(e)}"
                }

            responses.append(output)

    with open(output_path, 'w') as f:
        for r in responses:
            f.write(json.dumps(r) + '\n')

    print(f"Saved {len(responses)} results to {output_path}")

# %%
run_llama3_inference('../../samples_for_eval/zero_shot/llama/batch_input.jsonl', "../../samples_for_eval/zero_shot/llama/responses.jsonl")

# %% [markdown]
# ## upper_bound

# %%
def create_formatted_inputs_gold(row):
    
    return {
        "custom_id": f"{row.Entities}_{row.Label}:gold_injected",
        "method": "POST",
        "url": "/v1/chat/completions",  # still standard for OpenAI-compatible endpoints
        "body": {
            "model": "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo",  # adjust model name as per API
                        "messages": [
                {"role": "system", "content": SYSTEM_PROMPT_ZERO_SHOT},
                {"role": "user", "content": f"Question: {row.Question}\n\nGold Evidence:\n{row.Question_Back}\n\nAnswer:"}
                ]
        }
    }

formatted_samples = [create_formatted_inputs_gold(row) for row in test_df.itertuples()]
save_batch(formatted_samples, "../../samples_for_eval/upper_bound/llama/batch_input.jsonl")

# %%
run_llama3_inference('../../samples_for_eval/upper_bound/llama/batch_input.jsonl', "../../samples_for_eval/upper_bound/llama/responses.jsonl")

# %% [markdown]
# # TxGemma

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
tokenizer = AutoTokenizer.from_pretrained("google/txgemma-9b-chat")
model = AutoModelForCausalLM.from_pretrained("google/txgemma-9b-chat", device_map="auto", quantization_config=BitsAndBytesConfig(load_in_8bit=True))
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
def create_formatted_inputs_for_txgemma_zeroshot(row):
    return {
        "custom_id": f"{row.Entities}_{row.Label}:zero_shot",
        "input_text": f"{SYSTEM_PROMPT_ZERO_SHOT}\n\nQuestion: {row.Question}\n\nAnswer:"
    }

def create_formatted_inputs_for_txgemma_upperbound(row):
    return {
        "custom_id": f"{row.Entities}_{row.Label}:upper_bound",
        "input_text": f"{SYSTEM_PROMPT_UPPER_BOUND}\n\n{USER_PROMPT_UPPER_BOUND.format(row.Question_Background, row.Question)}"
    }

# %%
formatted_samples = [create_formatted_inputs_for_txgemma_zeroshot(row) for row in test_df.itertuples()]
save_batch(formatted_samples, "../../samples_for_eval/zero_shot/txgemma/batch_input.jsonl")

# %%
formatted_samples = [create_formatted_inputs_for_txgemma_gold(row) for row in test_df.itertuples()]
save_batch(formatted_samples, "../../samples_for_eval/upper_bound/txgemma/batch_input.jsonl")

# %%
run_txgemma_inference("../../samples_for_eval/zero_shot/txgemma/batch_input.jsonl", "../../samples_for_eval/zero_shot/txgemma/responses_new.jsonl",pipe)
# Out:
# Found 0 completed responses. Resuming...
# Processed: Candesartan-Citalopram-Fluphenazine-Histamine H1 receptor_8:zero_shot
# Processed: Lamotrigine-Oxaprozin-Sildenafil_4:zero_shot
# Processed: Ranitidine-Sibutramine-Zolpidem_4:zero_shot
# Processed: Cetirizine-Dipyridamole-Sildenafil-Zaleplon_2:zero_shot
# Processed: Alprazolam-Bumetanide-Fenofibrate-Modafinil_5:zero_shot
# Processed: alendronic acid-Pyridostigmine_0:zero_shot
# Processed: Ketorolac-Oxaprozin_0:zero_shot
# Processed: Naproxen-Doxazosin-Alpha-1B adrenergic receptor_7:zero_shot
# Processed: Chloroquine-hydroxychloroquine_3:zero_shot
# Processed: Amlodipine-Pamidronic acid-thiotepa_1:zero_shot
# Processed: Diazepam-Duloxetine-Acamprosate_4:zero_shot
# Processed: Tramadol-Exemestane_0:zero_shot
# Processed: Haloperidol-Muscarinic acetylcholine receptor M5_6:zero_shot
# Processed: Alprazolam-Ciclopirox_3:zero_shot
# Processed: Norfloxacin-Zolpidem-vincristine-Torasemide_2:zero_shot
# Processed: Naproxen-Ondansetron-Salmeterol-Beta-1 adrenergic receptor_8:zero_shot
# Processed: Cetirizine-Temozolomide_0:zero_shot
# Processed: Ziprasidone-Acamprosate_3:zero_shot
# Processed: Orphenadrine-Sumatriptan_0:zero_shot
# Processed: Triazolam-Rosiglitazone-Bimatoprost_1:zero_shot
# Processed: Furosemide-melphalan_0:zero_shot
# Processed: Fentanyl-desvenlafaxine_0:zero_shot
# Processed: Alprazolam-Ciclopirox_0:zero_shot
# Processed: Temazepam-Zafirlukast_3:zero_shot
# Processed: Ondansetron-Pirbuterol_0:zero_shot
# Processed: Temazepam-Zafirlukast-Cysteinyl leukotriene receptor 1_7:zero_shot
# Processed: Temazepam-Megestrol-Desloratadine-Darunavir_2:zero_shot
# Processed: Alprazolam-Benazepril_3:zero_shot
# Processed: Diazepam-Doxazosin_3:zero_shot
# Processed: Risedronic acid-Imatinib_0:zero_shot
# Processed: Norfloxacin-Zolpidem_0:zero_shot
# Processed: Alprazolam-Bumetanide_0:zero_shot
# Processed: Celecoxib-Oxaprozin-Sildenafil_1:zero_shot
# Processed: Rofecoxib-Telmisartan-solifenacin_4:zero_shot
# Processed: Carvedilol-Darunavir_0:zero_shot
# Processed: Lidocaine-Pamidronic acid-thiotepa_1:zero_shot
# Processed: Loxapine-Histamine H1 receptor_6:zero_shot
# Processed: Carvedilol-Darunavir_3:zero_shot
# Processed: Triazolam-Zaleplon_3:zero_shot
# Processed: Fluorouracil-vincristine_3:zero_shot
# Processed: Haloperidol-Histamine H1 receptor_6:zero_shot
# Processed: Naproxen-Norfloxacin_3:zero_shot
# Processed: Naproxen-alendronic acid-Salmeterol-Beta-1 adrenergic receptor_8:zero_shot
# Processed: Orphenadrine-Temazepam_3:zero_shot
# Processed: alendronic acid-Indapamide_3:zero_shot
# Processed: Fentanyl-Labetalol-Alpha-1B adrenergic receptor_7:zero_shot
# Processed: Naproxen-Lamotrigine-Zolpidem_1:zero_shot
# Processed: Lamotrigine-Salmeterol-Beta-3 adrenergic receptor_7:zero_shot
# Processed: Lamotrigine-Zaleplon_0:zero_shot
# Processed: alendronic acid-Alprazolam-Doxazosin-Alpha-1B adrenergic receptor_8:zero_shot
# Processed: Haloperidol-oxybutynin_0:zero_shot
# Processed: Carvedilol-Ibuprofen-Midodrine_1:zero_shot
# Processed: Carvedilol-Metolazone-Metoprolol-Alpha-2C adrenergic receptor_8:zero_shot
# Processed: Fluorouracil-mitomycin C_3:zero_shot
# Processed: Ziprasidone-Desloratadine_0:zero_shot
# Processed: alendronic acid-Lamivudine-Metoprolol-Perphenazine_5:zero_shot
# Processed: Cimetidine-Citalopram-nevirapine-oxybutynin_2:zero_shot
# Processed: Celecoxib-Midodrine_3:zero_shot
# Processed: Metronidazole-Fosphenytoin_3:zero_shot
# Processed: Lamotrigine-Oxaprozin_3:zero_shot
# Processed: Candesartan-Perindopril_3:zero_shot
# Processed: Bumetanide-Ranolazine_3:zero_shot
# Processed: Methylphenidate-Ofloxacin-Imatinib_4:zero_shot
# Processed: Rofecoxib-Triazolam_0:zero_shot
# Processed: Celecoxib-Labetalol_3:zero_shot
# Processed: indometacin-oxybutynin_3:zero_shot
# Processed: Famotidine-Pirbuterol_0:zero_shot
# Processed: Ranitidine-Sibutramine-Zolpidem-vincristine_5:zero_shot
# Processed: Fentanyl-Ketorolac-oxybutynin-Zaleplon_5:zero_shot
# Processed: Labetalol-Metoprolol-Perphenazine-Alpha-2A adrenergic receptor_8:zero_shot
# Processed: alendronic acid-Efavirenz-Lamivudine-Metoprolol_2:zero_shot
# Processed: Amlodipine-Rosiglitazone_0:zero_shot
# Processed: Fentanyl-Labetalol-Metoprolol-Pirbuterol_2:zero_shot
# Processed: Bumetanide-Fenofibrate_0:zero_shot
# Processed: Famotidine-Pilocarpine_3:zero_shot
# Processed: Fentanyl-Loxapine-Alpha-2C adrenergic receptor_7:zero_shot
# Processed: Naproxen-Zolpidem_0:zero_shot
# Processed: Furosemide-vincristine_0:zero_shot
# Processed: Ketorolac-Duloxetine_0:zero_shot
# Processed: Furosemide-hydralazine_3:zero_shot
# Processed: Diazepam-Desloratadine_3:zero_shot
# Processed: Haloperidol-indometacin-vincristine-Torasemide_5:zero_shot
# Processed: Theophylline-Bumetanide-vincristine-Torasemide_5:zero_shot
# Processed: Naproxen-Carvedilol_0:zero_shot
# Processed: Diazepam-Temozolomide-Thalidomide_4:zero_shot
# Processed: alendronic acid-Imatinib_3:zero_shot
# Processed: Risedronic acid-Trazodone-Alpha-2C adrenergic receptor_7:zero_shot
# Processed: Rofecoxib-Zolpidem-vincristine-Torasemide_2:zero_shot
# Processed: Candesartan-Fenofibrate-Modafinil-Bimatoprost_2:zero_shot
# Processed: Diazepam-Ofloxacin_0:zero_shot
# Processed: Pamidronic acid-thiotepa_3:zero_shot
# Processed: Cimetidine-Labetalol-Metoprolol-Prostacyclin receptor_8:zero_shot
# Processed: Naproxen-Furosemide-Zolpidem-vincristine_5:zero_shot
# Processed: Fentanyl-vincristine_3:zero_shot
# Processed: Diazepam-Temozolomide_3:zero_shot
# Processed: Efavirenz-Lamivudine_0:zero_shot
# Processed: Aciclovir-Azelastine_0:zero_shot
# Processed: indometacin-Terazosin_0:zero_shot
# Processed: Ofloxacin-Darunavir_3:zero_shot
# Processed: Fentanyl-Labetalol_0:zero_shot
# Processed: indometacin-Sildenafil_0:zero_shot
# Processed: Citalopram-Propofol_0:zero_shot
# Processed: Triazolam-Rosiglitazone-Bimatoprost_4:zero_shot
# Processed: Naproxen-Gabapentin_0:zero_shot
# Processed: Duloxetine-Desloratadine_3:zero_shot
# Processed: Loxapine-Muscarinic acetylcholine receptor M4_6:zero_shot
# Processed: indometacin-vincristine-Torasemide_1:zero_shot
# Processed: Cimetidine-Duloxetine_3:zero_shot
# Processed: Amlodipine-Metolazone-Metoprolol-Gastrin-releasing peptide receptor_8:zero_shot
# Processed: Gabapentin-Ibuprofen_0:zero_shot
# Processed: Furosemide-Salmeterol_3:zero_shot
# Processed: Amlodipine-Sufentanil_0:zero_shot
# Processed: Fentanyl-Trimethoprim_0:zero_shot
# Processed: Tolbutamide-Perindopril_0:zero_shot
# Processed: Naproxen-Lamotrigine_3:zero_shot
# Processed: Ibuprofen-desvenlafaxine_3:zero_shot
# Processed: Candesartan-Citalopram_3:zero_shot
# Processed: Amlodipine-Exemestane_0:zero_shot
# Processed: Ofloxacin-Imatinib_3:zero_shot
# Processed: Labetalol-Beta-3 adrenergic receptor_6:zero_shot
# Processed: Cimetidine-Histamine H2 receptor_6:zero_shot
# Processed: chlortalidone-Sildenafil-Zaleplon_1:zero_shot
# Processed: Cimetidine-Sumatriptan-Balsalazide_1:zero_shot
# Processed: Cimetidine-Labetalol-Alpha-1D adrenergic receptor_7:zero_shot
# Processed: Famotidine-Ticlopidine_3:zero_shot
# Processed: Naproxen-Cetirizine-Salmeterol_4:zero_shot
# Processed: phenytoin-Dapsone-Pyrimethamine-Muscarinic acetylcholine receptor M1_8:zero_shot
# Processed: Ziprasidone-Desloratadine-Telithromycin_1:zero_shot
# Processed: Naproxen-Carvedilol_3:zero_shot
# Processed: Candesartan-mitomycin C-vincristine-Torasemide_5:zero_shot
# Processed: Gabapentin-Amiloride_0:zero_shot
# Processed: Fentanyl-Trazodone_3:zero_shot
# Processed: Lidocaine-vincristine-Torasemide_4:zero_shot
# Processed: Carvedilol-Dobutamine_0:zero_shot
# Processed: Citalopram-Zolpidem_0:zero_shot
# Processed: Fentanyl-Labetalol-Alpha-2A adrenergic receptor_7:zero_shot
# Processed: Fluorouracil-Fulvestrant_3:zero_shot
# Processed: Zolpidem-vincristine_3:zero_shot
# Processed: Cimetidine-hydroxychloroquine_3:zero_shot
# Processed: Naproxen-Zolpidem-vincristine-Torasemide_5:zero_shot
# Processed: Citalopram-Isoniazid-Emtricitabine_4:zero_shot
# Processed: Carbachol-Muscarinic acetylcholine receptor M5_6:zero_shot
# Processed: acetazolamide-Haloperidol-Rosiglitazone-Bimatoprost_2:zero_shot
# Processed: Naproxen-alendronic acid_0:zero_shot
# Processed: Aciclovir-Doxazosin-Alpha-1B adrenergic receptor_7:zero_shot
# Processed: Risedronic acid-Zolpidem_3:zero_shot
# Processed: Amlodipine-vincristine_0:zero_shot
# Processed: Temazepam-Trimipramine-Histamine H1 receptor_7:zero_shot
# Processed: Naproxen-Risedronic acid-vincristine-Torasemide_2:zero_shot
# Processed: Duloxetine-desvenlafaxine_3:zero_shot
# Processed: Aciclovir-Dipyridamole_0:zero_shot
# Processed: Celecoxib-Palonosetron_0:zero_shot
# Processed: Methylphenidate-Modafinil-Pamidronic acid-thiotepa_5:zero_shot
# Processed: Desloratadine-solifenacin_0:zero_shot
# Processed: Naproxen-hydroxychloroquine_3:zero_shot
# Processed: Citalopram-Fenofibrate_0:zero_shot
# Processed: Telmisartan-Cinacalcet_0:zero_shot
# Processed: Rofecoxib-Torasemide_3:zero_shot
# Processed: Lamotrigine-Dexpramipexole_3:zero_shot
# Processed: Alprazolam-Doxazosin_0:zero_shot
# Processed: Ciclopirox-hydroxychloroquine_0:zero_shot
# Processed: alendronic acid-Ibuprofen_3:zero_shot
# Processed: Celecoxib-Labetalol-Metoprolol-Gastrin-releasing peptide receptor_8:zero_shot
# Processed: Duloxetine-Darunavir_0:zero_shot
# Processed: Minoxidil-Perindopril_3:zero_shot
# Processed: Oxaprozin-Sildenafil_3:zero_shot
# Processed: Ibuprofen-Repaglinide_3:zero_shot
# Processed: Trazodone-Alpha-2C adrenergic receptor_6:zero_shot

# %%
run_txgemma_inference("../../samples_for_eval/upper_bound/txgemma/batch_input.jsonl", "../../samples_for_eval/upper_bound/txgemma/responses_new.jsonl",pipe)
# Out:
# Found 0 completed responses. Resuming...
# Processed: Candesartan-Citalopram-Fluphenazine-Histamine H1 receptor_8:gold_injected
# Processed: Lamotrigine-Oxaprozin-Sildenafil_4:gold_injected
# Processed: Ranitidine-Sibutramine-Zolpidem_4:gold_injected
# Processed: Cetirizine-Dipyridamole-Sildenafil-Zaleplon_2:gold_injected
# Processed: Alprazolam-Bumetanide-Fenofibrate-Modafinil_5:gold_injected
# Processed: alendronic acid-Pyridostigmine_0:gold_injected
# Processed: Ketorolac-Oxaprozin_0:gold_injected
# Processed: Naproxen-Doxazosin-Alpha-1B adrenergic receptor_7:gold_injected
# Processed: Chloroquine-hydroxychloroquine_3:gold_injected
# Processed: Amlodipine-Pamidronic acid-thiotepa_1:gold_injected
# Processed: Diazepam-Duloxetine-Acamprosate_4:gold_injected
# Processed: Tramadol-Exemestane_0:gold_injected
# Processed: Haloperidol-Muscarinic acetylcholine receptor M5_6:gold_injected
# Processed: Alprazolam-Ciclopirox_3:gold_injected
# Processed: Norfloxacin-Zolpidem-vincristine-Torasemide_2:gold_injected
# Processed: Naproxen-Ondansetron-Salmeterol-Beta-1 adrenergic receptor_8:gold_injected
# Processed: Cetirizine-Temozolomide_0:gold_injected
# Processed: Ziprasidone-Acamprosate_3:gold_injected
# Processed: Orphenadrine-Sumatriptan_0:gold_injected
# Processed: Triazolam-Rosiglitazone-Bimatoprost_1:gold_injected
# Processed: Furosemide-melphalan_0:gold_injected
# Processed: Fentanyl-desvenlafaxine_0:gold_injected
# Processed: Alprazolam-Ciclopirox_0:gold_injected
# Processed: Temazepam-Zafirlukast_3:gold_injected
# Processed: Ondansetron-Pirbuterol_0:gold_injected
# Processed: Temazepam-Zafirlukast-Cysteinyl leukotriene receptor 1_7:gold_injected
# Processed: Temazepam-Megestrol-Desloratadine-Darunavir_2:gold_injected
# Processed: Alprazolam-Benazepril_3:gold_injected
# Processed: Diazepam-Doxazosin_3:gold_injected
# Processed: Risedronic acid-Imatinib_0:gold_injected
# Processed: Norfloxacin-Zolpidem_0:gold_injected
# Processed: Alprazolam-Bumetanide_0:gold_injected
# Processed: Celecoxib-Oxaprozin-Sildenafil_1:gold_injected
# Processed: Rofecoxib-Telmisartan-solifenacin_4:gold_injected
# Processed: Carvedilol-Darunavir_0:gold_injected
# Processed: Lidocaine-Pamidronic acid-thiotepa_1:gold_injected
# Processed: Loxapine-Histamine H1 receptor_6:gold_injected
# Processed: Carvedilol-Darunavir_3:gold_injected
# Processed: Triazolam-Zaleplon_3:gold_injected
# Processed: Fluorouracil-vincristine_3:gold_injected
# Processed: Haloperidol-Histamine H1 receptor_6:gold_injected
# Processed: Naproxen-Norfloxacin_3:gold_injected
# Processed: Naproxen-alendronic acid-Salmeterol-Beta-1 adrenergic receptor_8:gold_injected
# Processed: Orphenadrine-Temazepam_3:gold_injected
# Processed: alendronic acid-Indapamide_3:gold_injected
# Processed: Fentanyl-Labetalol-Alpha-1B adrenergic receptor_7:gold_injected
# Processed: Naproxen-Lamotrigine-Zolpidem_1:gold_injected
# Processed: Lamotrigine-Salmeterol-Beta-3 adrenergic receptor_7:gold_injected
# Processed: Lamotrigine-Zaleplon_0:gold_injected
# Processed: alendronic acid-Alprazolam-Doxazosin-Alpha-1B adrenergic receptor_8:gold_injected
# Processed: Haloperidol-oxybutynin_0:gold_injected
# Processed: Carvedilol-Ibuprofen-Midodrine_1:gold_injected
# Processed: Carvedilol-Metolazone-Metoprolol-Alpha-2C adrenergic receptor_8:gold_injected
# Processed: Fluorouracil-mitomycin C_3:gold_injected
# Processed: Ziprasidone-Desloratadine_0:gold_injected
# Processed: alendronic acid-Lamivudine-Metoprolol-Perphenazine_5:gold_injected
# Processed: Cimetidine-Citalopram-nevirapine-oxybutynin_2:gold_injected
# Processed: Celecoxib-Midodrine_3:gold_injected
# Processed: Metronidazole-Fosphenytoin_3:gold_injected
# Processed: Lamotrigine-Oxaprozin_3:gold_injected
# Processed: Candesartan-Perindopril_3:gold_injected
# Processed: Bumetanide-Ranolazine_3:gold_injected
# Processed: Methylphenidate-Ofloxacin-Imatinib_4:gold_injected
# Processed: Rofecoxib-Triazolam_0:gold_injected
# Processed: Celecoxib-Labetalol_3:gold_injected
# Processed: indometacin-oxybutynin_3:gold_injected
# Processed: Famotidine-Pirbuterol_0:gold_injected
# Processed: Ranitidine-Sibutramine-Zolpidem-vincristine_5:gold_injected
# Processed: Fentanyl-Ketorolac-oxybutynin-Zaleplon_5:gold_injected
# Processed: Labetalol-Metoprolol-Perphenazine-Alpha-2A adrenergic receptor_8:gold_injected
# Processed: alendronic acid-Efavirenz-Lamivudine-Metoprolol_2:gold_injected
# Processed: Amlodipine-Rosiglitazone_0:gold_injected
# Processed: Fentanyl-Labetalol-Metoprolol-Pirbuterol_2:gold_injected
# Processed: Bumetanide-Fenofibrate_0:gold_injected
# Processed: Famotidine-Pilocarpine_3:gold_injected
# Processed: Fentanyl-Loxapine-Alpha-2C adrenergic receptor_7:gold_injected
# Processed: Naproxen-Zolpidem_0:gold_injected
# Processed: Furosemide-vincristine_0:gold_injected
# Processed: Ketorolac-Duloxetine_0:gold_injected
# Processed: Furosemide-hydralazine_3:gold_injected
# Processed: Diazepam-Desloratadine_3:gold_injected
# Processed: Haloperidol-indometacin-vincristine-Torasemide_5:gold_injected
# Processed: Theophylline-Bumetanide-vincristine-Torasemide_5:gold_injected
# Processed: Naproxen-Carvedilol_0:gold_injected
# Processed: Diazepam-Temozolomide-Thalidomide_4:gold_injected
# Processed: alendronic acid-Imatinib_3:gold_injected
# Processed: Risedronic acid-Trazodone-Alpha-2C adrenergic receptor_7:gold_injected
# Processed: Rofecoxib-Zolpidem-vincristine-Torasemide_2:gold_injected
# Processed: Candesartan-Fenofibrate-Modafinil-Bimatoprost_2:gold_injected
# Processed: Diazepam-Ofloxacin_0:gold_injected
# Processed: Pamidronic acid-thiotepa_3:gold_injected
# Processed: Cimetidine-Labetalol-Metoprolol-Prostacyclin receptor_8:gold_injected
# Processed: Naproxen-Furosemide-Zolpidem-vincristine_5:gold_injected
# Processed: Fentanyl-vincristine_3:gold_injected
# Processed: Diazepam-Temozolomide_3:gold_injected
# Processed: Efavirenz-Lamivudine_0:gold_injected
# Processed: Aciclovir-Azelastine_0:gold_injected
# Processed: indometacin-Terazosin_0:gold_injected
# Processed: Ofloxacin-Darunavir_3:gold_injected
# Processed: Fentanyl-Labetalol_0:gold_injected
# Processed: indometacin-Sildenafil_0:gold_injected
# Processed: Citalopram-Propofol_0:gold_injected
# Processed: Triazolam-Rosiglitazone-Bimatoprost_4:gold_injected
# Processed: Naproxen-Gabapentin_0:gold_injected
# Processed: Duloxetine-Desloratadine_3:gold_injected
# Processed: Loxapine-Muscarinic acetylcholine receptor M4_6:gold_injected
# Processed: indometacin-vincristine-Torasemide_1:gold_injected
# Processed: Cimetidine-Duloxetine_3:gold_injected
# Processed: Amlodipine-Metolazone-Metoprolol-Gastrin-releasing peptide receptor_8:gold_injected
# Processed: Gabapentin-Ibuprofen_0:gold_injected
# Processed: Furosemide-Salmeterol_3:gold_injected
# Processed: Amlodipine-Sufentanil_0:gold_injected
# Processed: Fentanyl-Trimethoprim_0:gold_injected
# Processed: Tolbutamide-Perindopril_0:gold_injected
# Processed: Naproxen-Lamotrigine_3:gold_injected
# Processed: Ibuprofen-desvenlafaxine_3:gold_injected
# Processed: Candesartan-Citalopram_3:gold_injected
# Processed: Amlodipine-Exemestane_0:gold_injected
# Processed: Ofloxacin-Imatinib_3:gold_injected
# Processed: Labetalol-Beta-3 adrenergic receptor_6:gold_injected
# Processed: Cimetidine-Histamine H2 receptor_6:gold_injected
# Processed: chlortalidone-Sildenafil-Zaleplon_1:gold_injected
# Processed: Cimetidine-Sumatriptan-Balsalazide_1:gold_injected
# Processed: Cimetidine-Labetalol-Alpha-1D adrenergic receptor_7:gold_injected
# Processed: Famotidine-Ticlopidine_3:gold_injected
# Processed: Naproxen-Cetirizine-Salmeterol_4:gold_injected
# Processed: phenytoin-Dapsone-Pyrimethamine-Muscarinic acetylcholine receptor M1_8:gold_injected
# Processed: Ziprasidone-Desloratadine-Telithromycin_1:gold_injected
# Processed: Naproxen-Carvedilol_3:gold_injected
# Processed: Candesartan-mitomycin C-vincristine-Torasemide_5:gold_injected
# Processed: Gabapentin-Amiloride_0:gold_injected
# Processed: Fentanyl-Trazodone_3:gold_injected
# Processed: Lidocaine-vincristine-Torasemide_4:gold_injected
# Processed: Carvedilol-Dobutamine_0:gold_injected
# Processed: Citalopram-Zolpidem_0:gold_injected
# Processed: Fentanyl-Labetalol-Alpha-2A adrenergic receptor_7:gold_injected
# Processed: Fluorouracil-Fulvestrant_3:gold_injected
# Processed: Zolpidem-vincristine_3:gold_injected
# Processed: Cimetidine-hydroxychloroquine_3:gold_injected
# Processed: Naproxen-Zolpidem-vincristine-Torasemide_5:gold_injected
# Processed: Citalopram-Isoniazid-Emtricitabine_4:gold_injected
# Processed: Carbachol-Muscarinic acetylcholine receptor M5_6:gold_injected
# Processed: acetazolamide-Haloperidol-Rosiglitazone-Bimatoprost_2:gold_injected
# Processed: Naproxen-alendronic acid_0:gold_injected
# Processed: Aciclovir-Doxazosin-Alpha-1B adrenergic receptor_7:gold_injected
# Processed: Risedronic acid-Zolpidem_3:gold_injected
# Processed: Amlodipine-vincristine_0:gold_injected
# Processed: Temazepam-Trimipramine-Histamine H1 receptor_7:gold_injected
# Processed: Naproxen-Risedronic acid-vincristine-Torasemide_2:gold_injected
# Processed: Duloxetine-desvenlafaxine_3:gold_injected
# Processed: Aciclovir-Dipyridamole_0:gold_injected
# Processed: Celecoxib-Palonosetron_0:gold_injected
# Processed: Methylphenidate-Modafinil-Pamidronic acid-thiotepa_5:gold_injected
# Processed: Desloratadine-solifenacin_0:gold_injected
# Processed: Naproxen-hydroxychloroquine_3:gold_injected
# Processed: Citalopram-Fenofibrate_0:gold_injected
# Processed: Telmisartan-Cinacalcet_0:gold_injected
# Processed: Rofecoxib-Torasemide_3:gold_injected
# Processed: Lamotrigine-Dexpramipexole_3:gold_injected
# Processed: Alprazolam-Doxazosin_0:gold_injected
# Processed: Ciclopirox-hydroxychloroquine_0:gold_injected
# Processed: alendronic acid-Ibuprofen_3:gold_injected
# Processed: Celecoxib-Labetalol-Metoprolol-Gastrin-releasing peptide receptor_8:gold_injected
# Processed: Duloxetine-Darunavir_0:gold_injected
# Processed: Minoxidil-Perindopril_3:gold_injected
# Processed: Oxaprozin-Sildenafil_3:gold_injected
# Processed: Ibuprofen-Repaglinide_3:gold_injected
# Processed: Trazodone-Alpha-2C adrenergic receptor_6:gold_injected

# %%
def run_txgemma_inference(input_path, output_path, pipe, max_tokens=256):
    completed_ids = set()
    if os.path.exists(output_path):
        with open(output_path, 'r') as f:
            for line in f:
                try:
                    obj = json.loads(line)
                    completed_ids.add(obj["custom_id"])
                except:
                    continue
    print(f"Found {len(completed_ids)} completed responses. Resuming...")

    with open(input_path, 'r') as f_in, open(output_path, 'a') as f_out:
        for line in f_in:
            sample = json.loads(line.strip())
            custom_id = sample["custom_id"]
            if custom_id in completed_ids:
                continue

            try:
                output = pipe(sample["input_text"], max_new_tokens=max_tokens)[0]["generated_text"]
                answer = output[len(sample["input_text"]):].strip()
            except Exception as e:
                answer = f"[ERROR] {str(e)}"

            result = {
                "custom_id": custom_id,
                "response": answer
            }
            f_out.write(json.dumps(result) + "\n")
            f_out.flush()
            print(f"Processed: {custom_id}")

# %% [markdown]
# ### example

# %%
### example
import json
from huggingface_hub import hf_hub_download

tdc_prompts_filepath = hf_hub_download(
    repo_id=model_id,
    filename="tdc_prompts.json",
)

with open(tdc_prompts_filepath, "r") as f:
    tdc_prompts_json = json.load(f)
